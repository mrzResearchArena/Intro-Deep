# %%
# Base Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
x = np.arange(1, 50000)

# %%
y = np.sin(4.0*np.log(x))*x**0.75

# %%
plt.plot(x, y)

# %%
relu = lambda x: x*(x>0)
