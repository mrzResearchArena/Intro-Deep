# %%
w  = 10.0        # Random weight initialization
lr = 0.01        # Learning rate

# %% [markdown]
# ###### We are trying to find the appropriate value of w. So that we could find the minimum value of F(w).
# #### $$F(w) = w^2 - 6w + 1971$$

# %%
def F(w):
    return (w**2.0) - (6.0*w) + 1971

# %% [markdown]
# ###### The first-order derivative of the above F(w), is
# #### $$F'(w) = 2w - 6$$

# %%
def dF(w):
    return (2.0*w) - 6.0

# %% [markdown]
# ###### Gradient Descent Optimization, is
# #### $$w = w - \eta \nabla_{w} F(w) $$
# ###### Gradient Ascent Optimization, is
# #### $$w = w + \eta \nabla_{w} F(w) $$
# ###### But, we are using gradient descent optimization here. Yes, you can use gradient ascent optimization also. :) Oh! wait! Please, multiply by -1 with dF(x). Because, minimizing the F(x) is the same as maximizing the -F(x).

# %%
vdw = 0.0
for epoch in range(1, 401):
    print('Epoch: {}, function value: f({:.4f})={:.4f}'.format(epoch, w, F(w)))
    
    vdw = (0.9 * vdw) + dF(w)
    w = w - (lr * vdw) # Gradient Descent Optimization
    # w = w + (lr * -dF(w))  # Gradient Ascent Optimization


print('\nThe approximate argument of the function: {:.4f}'.format(w))
print('The minimum approximate value of the function: {:.4f}'.format(F(w)))
print('\n\033[1;31mPlease observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.')
# Out:
# Epoch: 1, function value: f(10.0000)=2011.0000
# Epoch: 2, function value: f(9.8600)=2009.0596
# Epoch: 3, function value: f(9.5968)=2005.5178
# Epoch: 4, function value: f(9.2280)=2000.7878
# Epoch: 5, function value: f(8.7715)=1995.3101
# Epoch: 6, function value: f(8.2452)=1989.5123
# Epoch: 7, function value: f(7.6667)=1983.7778
# Epoch: 8, function value: f(7.0526)=1978.4238
# Epoch: 9, function value: f(6.4190)=1973.6893
# Epoch: 10, function value: f(5.7803)=1969.7299
# Epoch: 11, function value: f(5.1498)=1966.6218
# Epoch: 12, function value: f(4.5395)=1964.3699
# Epoch: 13, function value: f(3.9593)=1962.9203
# Epoch: 14, function value: f(3.4180)=1962.1747
# Epoch: 15, function value: f(2.9225)=1962.0060
# Epoch: 16, function value: f(2.4781)=1962.2724
# Epoch: 17, function value: f(2.0885)=1962.8308
# Epoch: 18, function value: f(1.7561)=1963.5472
# Epoch: 19, function value: f(1.4819)=1964.3047
# Epoch: 20, function value: f(1.2654)=1965.0087
# Epoch: 21, function value: f(1.1053)=1965.5899
# Epoch: 22, function value: f(0.9991)=1966.0037
# Epoch: 23, function value: f(0.9435)=1966.2292
# Epoch: 24, function value: f(0.9346)=1966.2658
# Epoch: 25, function value: f(0.9679)=1966.1294
# Epoch: 26, function value: f(1.0385)=1965.8473
# Epoch: 27, function value: f(1.1413)=1965.4547
# Epoch: 28, function value: f(1.2710)=1964.9894
# Epoch: 29, function value: f(1.4223)=1964.4892
# Epoch: 30, function value: f(1.5900)=1963.9881
# Epoch: 31, function value: f(1.7692)=1963.5150
# Epoch: 32, function value: f(1.9550)=1963.0920
# Epoch: 33, function value: f(2.1432)=1962.7342
# Epoch: 34, function value: f(2.3296)=1962.4494
# Epoch: 35, function value: f(2.5109)=1962.2392
# Epoch: 36, function value: f(2.6838)=1962.1000
# Epoch: 37, function value: f(2.8457)=1962.0238
# Epoch: 38, function value: f(2.9945)=1962.0000
# Epoch: 39, function value: f(3.1286)=1962.0165
# Epoch: 40, function value: f(3.2467)=1962.0608
# Epoch: 41, function value: f(3.3480)=1962.1211
# Epoch: 42, function value: f(3.4323)=1962.1868
# Epoch: 43, function value: f(3.4994)=1962.2494
# Epoch: 44, function value: f(3.5499)=1962.3024
# Epoch: 45, function value: f(3.5843)=1962.3414
# Epoch: 46, function value: f(3.6036)=1962.3643
# Epoch: 47, function value: f(3.6089)=1962.3708
# Epoch: 48, function value: f(3.6015)=1962.3618
# Epoch: 49, function value: f(3.5828)=1962.3396
# Epoch: 50, function value: f(3.5543)=1962.3072
# Epoch: 51, function value: f(3.5176)=1962.2679
# Epoch: 52, function value: f(3.4742)=1962.2248
# Epoch: 53, function value: f(3.4256)=1962.1811
# Epoch: 54, function value: f(3.3734)=1962.1394
# Epoch: 55, function value: f(3.3190)=1962.1017
# Epoch: 56, function value: f(3.2636)=1962.0695
# Epoch: 57, function value: f(3.2085)=1962.0435
# Epoch: 58, function value: f(3.1547)=1962.0239
# Epoch: 59, function value: f(3.1032)=1962.0106
# Epoch: 60, function value: f(3.0548)=1962.0030
# Epoch: 61, function value: f(3.0101)=1962.0001
# Epoch: 62, function value: f(2.9697)=1962.0009
# Epoch: 63, function value: f(2.9340)=1962.0044
# Epoch: 64, function value: f(2.9031)=1962.0094
# Epoch: 65, function value: f(2.8773)=1962.0151
# Epoch: 66, function value: f(2.8565)=1962.0206
# Epoch: 67, function value: f(2.8406)=1962.0254
# Epoch: 68, function value: f(2.8296)=1962.0290
# Epoch: 69, function value: f(2.8230)=1962.0313
# Epoch: 70, function value: f(2.8206)=1962.0322
# Epoch: 71, function value: f(2.8221)=1962.0316
# Epoch: 72, function value: f(2.8270)=1962.0299
# Epoch: 73, function value: f(2.8348)=1962.0273
# Epoch: 74, function value: f(2.8452)=1962.0240
# Epoch: 75, function value: f(2.8576)=1962.0203
# Epoch: 76, function value: f(2.8716)=1962.0165
# Epoch: 77, function value: f(2.8868)=1962.0128
# Epoch: 78, function value: f(2.9028)=1962.0095
# Epoch: 79, function value: f(2.9191)=1962.0066
# Epoch: 80, function value: f(2.9353)=1962.0042
# Epoch: 81, function value: f(2.9513)=1962.0024
# Epoch: 82, function value: f(2.9666)=1962.0011
# Epoch: 83, function value: f(2.9811)=1962.0004
# Epoch: 84, function value: f(2.9945)=1962.0000
# Epoch: 85, function value: f(3.0066)=1962.0000
# Epoch: 86, function value: f(3.0174)=1962.0003
# Epoch: 87, function value: f(3.0268)=1962.0007
# Epoch: 88, function value: f(3.0347)=1962.0012
# Epoch: 89, function value: f(3.0412)=1962.0017
# Epoch: 90, function value: f(3.0461)=1962.0021
# Epoch: 91, function value: f(3.0497)=1962.0025
# Epoch: 92, function value: f(3.0518)=1962.0027
# Epoch: 93, function value: f(3.0528)=1962.0028
# Epoch: 94, function value: f(3.0526)=1962.0028
# Epoch: 95, function value: f(3.0513)=1962.0026
# Epoch: 96, function value: f(3.0492)=1962.0024
# Epoch: 97, function value: f(3.0463)=1962.0021
# Epoch: 98, function value: f(3.0427)=1962.0018
# Epoch: 99, function value: f(3.0387)=1962.0015
# Epoch: 100, function value: f(3.0343)=1962.0012
# Epoch: 101, function value: f(3.0296)=1962.0009
# Epoch: 102, function value: f(3.0248)=1962.0006
# Epoch: 103, function value: f(3.0200)=1962.0004
# Epoch: 104, function value: f(3.0153)=1962.0002
# Epoch: 105, function value: f(3.0107)=1962.0001
# Epoch: 106, function value: f(3.0064)=1962.0000
# Epoch: 107, function value: f(3.0024)=1962.0000
# Epoch: 108, function value: f(2.9987)=1962.0000
# Epoch: 109, function value: f(2.9955)=1962.0000
# Epoch: 110, function value: f(2.9926)=1962.0001
# Epoch: 111, function value: f(2.9902)=1962.0001
# Epoch: 112, function value: f(2.9882)=1962.0001
# Epoch: 113, function value: f(2.9867)=1962.0002
# Epoch: 114, function value: f(2.9856)=1962.0002
# Epoch: 115, function value: f(2.9848)=1962.0002
# Epoch: 116, function value: f(2.9845)=1962.0002
# Epoch: 117, function value: f(2.9845)=1962.0002
# Epoch: 118, function value: f(2.9848)=1962.0002
# Epoch: 119, function value: f(2.9854)=1962.0002
# Epoch: 120, function value: f(2.9862)=1962.0002
# Epoch: 121, function value: f(2.9872)=1962.0002
# Epoch: 122, function value: f(2.9884)=1962.0001
# Epoch: 123, function value: f(2.9896)=1962.0001
# Epoch: 124, function value: f(2.9910)=1962.0001
# Epoch: 125, function value: f(2.9924)=1962.0001
# Epoch: 126, function value: f(2.9938)=1962.0000
# Epoch: 127, function value: f(2.9952)=1962.0000
# Epoch: 128, function value: f(2.9966)=1962.0000
# Epoch: 129, function value: f(2.9979)=1962.0000
# Epoch: 130, function value: f(2.9991)=1962.0000
# Epoch: 131, function value: f(3.0002)=1962.0000
# Epoch: 132, function value: f(3.0011)=1962.0000
# Epoch: 133, function value: f(3.0020)=1962.0000
# Epoch: 134, function value: f(3.0028)=1962.0000
# Epoch: 135, function value: f(3.0034)=1962.0000
# Epoch: 136, function value: f(3.0038)=1962.0000
# Epoch: 137, function value: f(3.0042)=1962.0000
# Epoch: 138, function value: f(3.0044)=1962.0000
# Epoch: 139, function value: f(3.0046)=1962.0000
# Epoch: 140, function value: f(3.0046)=1962.0000
# Epoch: 141, function value: f(3.0045)=1962.0000
# Epoch: 142, function value: f(3.0044)=1962.0000
# Epoch: 143, function value: f(3.0041)=1962.0000
# Epoch: 144, function value: f(3.0038)=1962.0000
# Epoch: 145, function value: f(3.0035)=1962.0000
# Epoch: 146, function value: f(3.0031)=1962.0000
# Epoch: 147, function value: f(3.0027)=1962.0000
# Epoch: 148, function value: f(3.0023)=1962.0000
# Epoch: 149, function value: f(3.0019)=1962.0000
# Epoch: 150, function value: f(3.0015)=1962.0000
# Epoch: 151, function value: f(3.0011)=1962.0000
# Epoch: 152, function value: f(3.0007)=1962.0000
# Epoch: 153, function value: f(3.0003)=1962.0000
# Epoch: 154, function value: f(3.0000)=1962.0000
# Epoch: 155, function value: f(2.9997)=1962.0000
# Epoch: 156, function value: f(2.9995)=1962.0000
# Epoch: 157, function value: f(2.9992)=1962.0000
# Epoch: 158, function value: f(2.9990)=1962.0000
# Epoch: 159, function value: f(2.9989)=1962.0000
# Epoch: 160, function value: f(2.9988)=1962.0000
# Epoch: 161, function value: f(2.9987)=1962.0000
# Epoch: 162, function value: f(2.9987)=1962.0000
# Epoch: 163, function value: f(2.9986)=1962.0000
# Epoch: 164, function value: f(2.9987)=1962.0000
# Epoch: 165, function value: f(2.9987)=1962.0000
# Epoch: 166, function value: f(2.9988)=1962.0000
# Epoch: 167, function value: f(2.9989)=1962.0000
# Epoch: 168, function value: f(2.9989)=1962.0000
# Epoch: 169, function value: f(2.9991)=1962.0000
# Epoch: 170, function value: f(2.9992)=1962.0000
# Epoch: 171, function value: f(2.9993)=1962.0000
# Epoch: 172, function value: f(2.9994)=1962.0000
# Epoch: 173, function value: f(2.9995)=1962.0000
# Epoch: 174, function value: f(2.9997)=1962.0000
# Epoch: 175, function value: f(2.9998)=1962.0000
# Epoch: 176, function value: f(2.9999)=1962.0000
# Epoch: 177, function value: f(3.0000)=1962.0000
# Epoch: 178, function value: f(3.0001)=1962.0000
# Epoch: 179, function value: f(3.0001)=1962.0000
# Epoch: 180, function value: f(3.0002)=1962.0000
# Epoch: 181, function value: f(3.0003)=1962.0000
# Epoch: 182, function value: f(3.0003)=1962.0000
# Epoch: 183, function value: f(3.0004)=1962.0000
# Epoch: 184, function value: f(3.0004)=1962.0000
# Epoch: 185, function value: f(3.0004)=1962.0000
# Epoch: 186, function value: f(3.0004)=1962.0000
# Epoch: 187, function value: f(3.0004)=1962.0000
# Epoch: 188, function value: f(3.0004)=1962.0000
# Epoch: 189, function value: f(3.0004)=1962.0000
# Epoch: 190, function value: f(3.0003)=1962.0000
# Epoch: 191, function value: f(3.0003)=1962.0000
# Epoch: 192, function value: f(3.0003)=1962.0000
# Epoch: 193, function value: f(3.0003)=1962.0000
# Epoch: 194, function value: f(3.0002)=1962.0000
# Epoch: 195, function value: f(3.0002)=1962.0000
# Epoch: 196, function value: f(3.0001)=1962.0000
# Epoch: 197, function value: f(3.0001)=1962.0000
# Epoch: 198, function value: f(3.0001)=1962.0000
# Epoch: 199, function value: f(3.0000)=1962.0000
# Epoch: 200, function value: f(3.0000)=1962.0000
# Epoch: 201, function value: f(3.0000)=1962.0000
# Epoch: 202, function value: f(3.0000)=1962.0000
# Epoch: 203, function value: f(2.9999)=1962.0000
# Epoch: 204, function value: f(2.9999)=1962.0000
# Epoch: 205, function value: f(2.9999)=1962.0000
# Epoch: 206, function value: f(2.9999)=1962.0000
# Epoch: 207, function value: f(2.9999)=1962.0000
# Epoch: 208, function value: f(2.9999)=1962.0000
# Epoch: 209, function value: f(2.9999)=1962.0000
# Epoch: 210, function value: f(2.9999)=1962.0000
# Epoch: 211, function value: f(2.9999)=1962.0000
# Epoch: 212, function value: f(2.9999)=1962.0000
# Epoch: 213, function value: f(2.9999)=1962.0000
# Epoch: 214, function value: f(2.9999)=1962.0000
# Epoch: 215, function value: f(2.9999)=1962.0000
# Epoch: 216, function value: f(2.9999)=1962.0000
# Epoch: 217, function value: f(2.9999)=1962.0000
# Epoch: 218, function value: f(2.9999)=1962.0000
# Epoch: 219, function value: f(3.0000)=1962.0000
# Epoch: 220, function value: f(3.0000)=1962.0000
# Epoch: 221, function value: f(3.0000)=1962.0000
# Epoch: 222, function value: f(3.0000)=1962.0000
# Epoch: 223, function value: f(3.0000)=1962.0000
# Epoch: 224, function value: f(3.0000)=1962.0000
# Epoch: 225, function value: f(3.0000)=1962.0000
# Epoch: 226, function value: f(3.0000)=1962.0000
# Epoch: 227, function value: f(3.0000)=1962.0000
# Epoch: 228, function value: f(3.0000)=1962.0000
# Epoch: 229, function value: f(3.0000)=1962.0000
# Epoch: 230, function value: f(3.0000)=1962.0000
# Epoch: 231, function value: f(3.0000)=1962.0000
# Epoch: 232, function value: f(3.0000)=1962.0000
# Epoch: 233, function value: f(3.0000)=1962.0000
# Epoch: 234, function value: f(3.0000)=1962.0000
# Epoch: 235, function value: f(3.0000)=1962.0000
# Epoch: 236, function value: f(3.0000)=1962.0000
# Epoch: 237, function value: f(3.0000)=1962.0000
# Epoch: 238, function value: f(3.0000)=1962.0000
# Epoch: 239, function value: f(3.0000)=1962.0000
# Epoch: 240, function value: f(3.0000)=1962.0000
# Epoch: 241, function value: f(3.0000)=1962.0000
# Epoch: 242, function value: f(3.0000)=1962.0000
# Epoch: 243, function value: f(3.0000)=1962.0000
# Epoch: 244, function value: f(3.0000)=1962.0000
# Epoch: 245, function value: f(3.0000)=1962.0000
# Epoch: 246, function value: f(3.0000)=1962.0000
# Epoch: 247, function value: f(3.0000)=1962.0000
# Epoch: 248, function value: f(3.0000)=1962.0000
# Epoch: 249, function value: f(3.0000)=1962.0000
# Epoch: 250, function value: f(3.0000)=1962.0000
# Epoch: 251, function value: f(3.0000)=1962.0000
# Epoch: 252, function value: f(3.0000)=1962.0000
# Epoch: 253, function value: f(3.0000)=1962.0000
# Epoch: 254, function value: f(3.0000)=1962.0000
# Epoch: 255, function value: f(3.0000)=1962.0000
# Epoch: 256, function value: f(3.0000)=1962.0000
# Epoch: 257, function value: f(3.0000)=1962.0000
# Epoch: 258, function value: f(3.0000)=1962.0000
# Epoch: 259, function value: f(3.0000)=1962.0000
# Epoch: 260, function value: f(3.0000)=1962.0000
# Epoch: 261, function value: f(3.0000)=1962.0000
# Epoch: 262, function value: f(3.0000)=1962.0000
# Epoch: 263, function value: f(3.0000)=1962.0000
# Epoch: 264, function value: f(3.0000)=1962.0000
# Epoch: 265, function value: f(3.0000)=1962.0000
# Epoch: 266, function value: f(3.0000)=1962.0000
# Epoch: 267, function value: f(3.0000)=1962.0000
# Epoch: 268, function value: f(3.0000)=1962.0000
# Epoch: 269, function value: f(3.0000)=1962.0000
# Epoch: 270, function value: f(3.0000)=1962.0000
# Epoch: 271, function value: f(3.0000)=1962.0000
# Epoch: 272, function value: f(3.0000)=1962.0000
# Epoch: 273, function value: f(3.0000)=1962.0000
# Epoch: 274, function value: f(3.0000)=1962.0000
# Epoch: 275, function value: f(3.0000)=1962.0000
# Epoch: 276, function value: f(3.0000)=1962.0000
# Epoch: 277, function value: f(3.0000)=1962.0000
# Epoch: 278, function value: f(3.0000)=1962.0000
# Epoch: 279, function value: f(3.0000)=1962.0000
# Epoch: 280, function value: f(3.0000)=1962.0000
# Epoch: 281, function value: f(3.0000)=1962.0000
# Epoch: 282, function value: f(3.0000)=1962.0000
# Epoch: 283, function value: f(3.0000)=1962.0000
# Epoch: 284, function value: f(3.0000)=1962.0000
# Epoch: 285, function value: f(3.0000)=1962.0000
# Epoch: 286, function value: f(3.0000)=1962.0000
# Epoch: 287, function value: f(3.0000)=1962.0000
# Epoch: 288, function value: f(3.0000)=1962.0000
# Epoch: 289, function value: f(3.0000)=1962.0000
# Epoch: 290, function value: f(3.0000)=1962.0000
# Epoch: 291, function value: f(3.0000)=1962.0000
# Epoch: 292, function value: f(3.0000)=1962.0000
# Epoch: 293, function value: f(3.0000)=1962.0000
# Epoch: 294, function value: f(3.0000)=1962.0000
# Epoch: 295, function value: f(3.0000)=1962.0000
# Epoch: 296, function value: f(3.0000)=1962.0000
# Epoch: 297, function value: f(3.0000)=1962.0000
# Epoch: 298, function value: f(3.0000)=1962.0000
# Epoch: 299, function value: f(3.0000)=1962.0000
# Epoch: 300, function value: f(3.0000)=1962.0000
# Epoch: 301, function value: f(3.0000)=1962.0000
# Epoch: 302, function value: f(3.0000)=1962.0000
# Epoch: 303, function value: f(3.0000)=1962.0000
# Epoch: 304, function value: f(3.0000)=1962.0000
# Epoch: 305, function value: f(3.0000)=1962.0000
# Epoch: 306, function value: f(3.0000)=1962.0000
# Epoch: 307, function value: f(3.0000)=1962.0000
# Epoch: 308, function value: f(3.0000)=1962.0000
# Epoch: 309, function value: f(3.0000)=1962.0000
# Epoch: 310, function value: f(3.0000)=1962.0000
# Epoch: 311, function value: f(3.0000)=1962.0000
# Epoch: 312, function value: f(3.0000)=1962.0000
# Epoch: 313, function value: f(3.0000)=1962.0000
# Epoch: 314, function value: f(3.0000)=1962.0000
# Epoch: 315, function value: f(3.0000)=1962.0000
# Epoch: 316, function value: f(3.0000)=1962.0000
# Epoch: 317, function value: f(3.0000)=1962.0000
# Epoch: 318, function value: f(3.0000)=1962.0000
# Epoch: 319, function value: f(3.0000)=1962.0000
# Epoch: 320, function value: f(3.0000)=1962.0000
# Epoch: 321, function value: f(3.0000)=1962.0000
# Epoch: 322, function value: f(3.0000)=1962.0000
# Epoch: 323, function value: f(3.0000)=1962.0000
# Epoch: 324, function value: f(3.0000)=1962.0000
# Epoch: 325, function value: f(3.0000)=1962.0000
# Epoch: 326, function value: f(3.0000)=1962.0000
# Epoch: 327, function value: f(3.0000)=1962.0000
# Epoch: 328, function value: f(3.0000)=1962.0000
# Epoch: 329, function value: f(3.0000)=1962.0000
# Epoch: 330, function value: f(3.0000)=1962.0000
# Epoch: 331, function value: f(3.0000)=1962.0000
# Epoch: 332, function value: f(3.0000)=1962.0000
# Epoch: 333, function value: f(3.0000)=1962.0000
# Epoch: 334, function value: f(3.0000)=1962.0000
# Epoch: 335, function value: f(3.0000)=1962.0000
# Epoch: 336, function value: f(3.0000)=1962.0000
# Epoch: 337, function value: f(3.0000)=1962.0000
# Epoch: 338, function value: f(3.0000)=1962.0000
# Epoch: 339, function value: f(3.0000)=1962.0000
# Epoch: 340, function value: f(3.0000)=1962.0000
# Epoch: 341, function value: f(3.0000)=1962.0000
# Epoch: 342, function value: f(3.0000)=1962.0000
# Epoch: 343, function value: f(3.0000)=1962.0000
# Epoch: 344, function value: f(3.0000)=1962.0000
# Epoch: 345, function value: f(3.0000)=1962.0000
# Epoch: 346, function value: f(3.0000)=1962.0000
# Epoch: 347, function value: f(3.0000)=1962.0000
# Epoch: 348, function value: f(3.0000)=1962.0000
# Epoch: 349, function value: f(3.0000)=1962.0000
# Epoch: 350, function value: f(3.0000)=1962.0000
# Epoch: 351, function value: f(3.0000)=1962.0000
# Epoch: 352, function value: f(3.0000)=1962.0000
# Epoch: 353, function value: f(3.0000)=1962.0000
# Epoch: 354, function value: f(3.0000)=1962.0000
# Epoch: 355, function value: f(3.0000)=1962.0000
# Epoch: 356, function value: f(3.0000)=1962.0000
# Epoch: 357, function value: f(3.0000)=1962.0000
# Epoch: 358, function value: f(3.0000)=1962.0000
# Epoch: 359, function value: f(3.0000)=1962.0000
# Epoch: 360, function value: f(3.0000)=1962.0000
# Epoch: 361, function value: f(3.0000)=1962.0000
# Epoch: 362, function value: f(3.0000)=1962.0000
# Epoch: 363, function value: f(3.0000)=1962.0000
# Epoch: 364, function value: f(3.0000)=1962.0000
# Epoch: 365, function value: f(3.0000)=1962.0000
# Epoch: 366, function value: f(3.0000)=1962.0000
# Epoch: 367, function value: f(3.0000)=1962.0000
# Epoch: 368, function value: f(3.0000)=1962.0000
# Epoch: 369, function value: f(3.0000)=1962.0000
# Epoch: 370, function value: f(3.0000)=1962.0000
# Epoch: 371, function value: f(3.0000)=1962.0000
# Epoch: 372, function value: f(3.0000)=1962.0000
# Epoch: 373, function value: f(3.0000)=1962.0000
# Epoch: 374, function value: f(3.0000)=1962.0000
# Epoch: 375, function value: f(3.0000)=1962.0000
# Epoch: 376, function value: f(3.0000)=1962.0000
# Epoch: 377, function value: f(3.0000)=1962.0000
# Epoch: 378, function value: f(3.0000)=1962.0000
# Epoch: 379, function value: f(3.0000)=1962.0000
# Epoch: 380, function value: f(3.0000)=1962.0000
# Epoch: 381, function value: f(3.0000)=1962.0000
# Epoch: 382, function value: f(3.0000)=1962.0000
# Epoch: 383, function value: f(3.0000)=1962.0000
# Epoch: 384, function value: f(3.0000)=1962.0000
# Epoch: 385, function value: f(3.0000)=1962.0000
# Epoch: 386, function value: f(3.0000)=1962.0000
# Epoch: 387, function value: f(3.0000)=1962.0000
# Epoch: 388, function value: f(3.0000)=1962.0000
# Epoch: 389, function value: f(3.0000)=1962.0000
# Epoch: 390, function value: f(3.0000)=1962.0000
# Epoch: 391, function value: f(3.0000)=1962.0000
# Epoch: 392, function value: f(3.0000)=1962.0000
# Epoch: 393, function value: f(3.0000)=1962.0000
# Epoch: 394, function value: f(3.0000)=1962.0000
# Epoch: 395, function value: f(3.0000)=1962.0000
# Epoch: 396, function value: f(3.0000)=1962.0000
# Epoch: 397, function value: f(3.0000)=1962.0000
# Epoch: 398, function value: f(3.0000)=1962.0000
# Epoch: 399, function value: f(3.0000)=1962.0000
# Epoch: 400, function value: f(3.0000)=1962.0000
#
# The approximate argument of the function: 3.0000
# The minimum approximate value of the function: 1962.0000
#
# Please observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.
