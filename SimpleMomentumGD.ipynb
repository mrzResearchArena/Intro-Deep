# %%
w  = 10.0        # Random weight initialization
lr = 0.01        # Learning rate

# %% [markdown]
# ###### We are trying to find the appropriate value of w. So that we could find the minimum value of F(w).
# #### $$F(w) = w^2 - 6w + 1971$$

# %%
def F(w):
    return (w**2.0) - (6.0*w) + 1971

# %% [markdown]
# ###### The first-order derivative of the above F(w), is
# #### $$F'(w) = 2w - 6$$

# %%
def dF(w):
    return (2.0*w) - 6.0

# %% [markdown]
# ###### Gradient Descent Optimization, is
# #### $$w = w - \eta \nabla_{w} F(w) $$
# ###### Gradient Ascent Optimization, is
# #### $$w = w + \eta \nabla_{w} F(w) $$
# ###### But, we are using gradient descent optimization here. Yes, you can use gradient ascent optimization also. :) Oh! wait! Please, multiply by -1 with dF(x). Because, minimizing the F(x) is the same as maximizing the -F(x).

# %%
# Gradient Descent Optimization with Momemtum
vdw = 0.0
for epoch in range(1, 401): # Epoch
    print('Epoch: {}, function value: f({:.4f})={:.4f}'.format(epoch, w, F(w)))
    
    vdw = (0.9 * vdw) + (0.1 * dF(w)) # VdW = B*VdW + (1-B)*dW
    w = w - (lr * vdw)                # W   = W - (lr * VdW)
    

print('\nThe approximate argument of the function: {:.4f}'.format(w))
print('The minimum approximate value of the function: {:.4f}'.format(F(w)))
print('\n\033[1;31mPlease observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.')
# Out:
# Epoch: 1, function value: f(10.0000)=2011.0000
# Epoch: 2, function value: f(9.9860)=2010.8042
# Epoch: 3, function value: f(9.9594)=2010.4336
# Epoch: 4, function value: f(9.9216)=2009.9085
# Epoch: 5, function value: f(9.8737)=2009.2478
# Epoch: 6, function value: f(9.8168)=2008.4694
# Epoch: 7, function value: f(9.7520)=2007.5902
# Epoch: 8, function value: f(9.6802)=2006.6254
# Epoch: 9, function value: f(9.6022)=2005.5893
# Epoch: 10, function value: f(9.5188)=2004.4950
# Epoch: 11, function value: f(9.4307)=2003.3541
# Epoch: 12, function value: f(9.3386)=2002.1773
# Epoch: 13, function value: f(9.2429)=2000.9743
# Epoch: 14, function value: f(9.1444)=1999.7537
# Epoch: 15, function value: f(9.0434)=1998.5230
# Epoch: 16, function value: f(8.9405)=1997.2891
# Epoch: 17, function value: f(8.8359)=1996.0579
# Epoch: 18, function value: f(8.7301)=1994.8346
# Epoch: 19, function value: f(8.6235)=1993.6237
# Epoch: 20, function value: f(8.5163)=1992.4292
# Epoch: 21, function value: f(8.4087)=1991.2543
# Epoch: 22, function value: f(8.3011)=1990.1019
# Epoch: 23, function value: f(8.1937)=1988.9743
# Epoch: 24, function value: f(8.0866)=1987.8734
# Epoch: 25, function value: f(7.9800)=1986.8007
# Epoch: 26, function value: f(7.8742)=1985.7576
# Epoch: 27, function value: f(7.7692)=1984.7448
# Epoch: 28, function value: f(7.6651)=1983.7631
# Epoch: 29, function value: f(7.5621)=1982.8129
# Epoch: 30, function value: f(7.4603)=1981.8944
# Epoch: 31, function value: f(7.3598)=1981.0075
# Epoch: 32, function value: f(7.2605)=1980.1523
# Epoch: 33, function value: f(7.1627)=1979.3284
# Epoch: 34, function value: f(7.0664)=1978.5355
# Epoch: 35, function value: f(6.9715)=1977.7730
# Epoch: 36, function value: f(6.8782)=1977.0406
# Epoch: 37, function value: f(6.7865)=1976.3374
# Epoch: 38, function value: f(6.6963)=1975.6630
# Epoch: 39, function value: f(6.6078)=1975.0164
# Epoch: 40, function value: f(6.5210)=1974.3971
# Epoch: 41, function value: f(6.4357)=1973.8042
# Epoch: 42, function value: f(6.3521)=1973.2368
# Epoch: 43, function value: f(6.2702)=1972.6943
# Epoch: 44, function value: f(6.1899)=1972.1757
# Epoch: 45, function value: f(6.1113)=1971.6802
# Epoch: 46, function value: f(6.0343)=1971.2071
# Epoch: 47, function value: f(5.9590)=1970.7555
# Epoch: 48, function value: f(5.8852)=1970.3245
# Epoch: 49, function value: f(5.8131)=1969.9135
# Epoch: 50, function value: f(5.7425)=1969.5215
# Epoch: 51, function value: f(5.6736)=1969.1479
# Epoch: 52, function value: f(5.6061)=1968.7919
# Epoch: 53, function value: f(5.5402)=1968.4528
# Epoch: 54, function value: f(5.4758)=1968.1298
# Epoch: 55, function value: f(5.4129)=1967.8223
# Epoch: 56, function value: f(5.3515)=1967.5296
# Epoch: 57, function value: f(5.2915)=1967.2510
# Epoch: 58, function value: f(5.2329)=1966.9860
# Epoch: 59, function value: f(5.1757)=1966.7339
# Epoch: 60, function value: f(5.1199)=1966.4941
# Epoch: 61, function value: f(5.0654)=1966.2661
# Epoch: 62, function value: f(5.0123)=1966.0493
# Epoch: 63, function value: f(4.9604)=1965.8432
# Epoch: 64, function value: f(4.9098)=1965.6474
# Epoch: 65, function value: f(4.8605)=1965.4613
# Epoch: 66, function value: f(4.8123)=1965.2844
# Epoch: 67, function value: f(4.7653)=1965.1164
# Epoch: 68, function value: f(4.7196)=1964.9569
# Epoch: 69, function value: f(4.6749)=1964.8053
# Epoch: 70, function value: f(4.6314)=1964.6614
# Epoch: 71, function value: f(4.5889)=1964.5247
# Epoch: 72, function value: f(4.5475)=1964.3949
# Epoch: 73, function value: f(4.5072)=1964.2717
# Epoch: 74, function value: f(4.4679)=1964.1547
# Epoch: 75, function value: f(4.4296)=1964.0437
# Epoch: 76, function value: f(4.3922)=1963.9383
# Epoch: 77, function value: f(4.3558)=1963.8382
# Epoch: 78, function value: f(4.3204)=1963.7433
# Epoch: 79, function value: f(4.2858)=1963.6532
# Epoch: 80, function value: f(4.2521)=1963.5678
# Epoch: 81, function value: f(4.2193)=1963.4867
# Epoch: 82, function value: f(4.1873)=1963.4097
# Epoch: 83, function value: f(4.1562)=1963.3367
# Epoch: 84, function value: f(4.1258)=1963.2675
# Epoch: 85, function value: f(4.0963)=1963.2018
# Epoch: 86, function value: f(4.0675)=1963.1395
# Epoch: 87, function value: f(4.0394)=1963.0804
# Epoch: 88, function value: f(4.0121)=1963.0243
# Epoch: 89, function value: f(3.9855)=1962.9711
# Epoch: 90, function value: f(3.9595)=1962.9207
# Epoch: 91, function value: f(3.9343)=1962.8729
# Epoch: 92, function value: f(3.9097)=1962.8275
# Epoch: 93, function value: f(3.8857)=1962.7845
# Epoch: 94, function value: f(3.8624)=1962.7437
# Epoch: 95, function value: f(3.8397)=1962.7050
# Epoch: 96, function value: f(3.8175)=1962.6684
# Epoch: 97, function value: f(3.7960)=1962.6336
# Epoch: 98, function value: f(3.7750)=1962.6006
# Epoch: 99, function value: f(3.7545)=1962.5693
# Epoch: 100, function value: f(3.7346)=1962.5397
# Epoch: 101, function value: f(3.7153)=1962.5116
# Epoch: 102, function value: f(3.6964)=1962.4849
# Epoch: 103, function value: f(3.6780)=1962.4597
# Epoch: 104, function value: f(3.6601)=1962.4357
# Epoch: 105, function value: f(3.6427)=1962.4130
# Epoch: 106, function value: f(3.6257)=1962.3915
# Epoch: 107, function value: f(3.6092)=1962.3711
# Epoch: 108, function value: f(3.5931)=1962.3517
# Epoch: 109, function value: f(3.5774)=1962.3334
# Epoch: 110, function value: f(3.5622)=1962.3160
# Epoch: 111, function value: f(3.5473)=1962.2995
# Epoch: 112, function value: f(3.5328)=1962.2839
# Epoch: 113, function value: f(3.5187)=1962.2691
# Epoch: 114, function value: f(3.5050)=1962.2551
# Epoch: 115, function value: f(3.4917)=1962.2418
# Epoch: 116, function value: f(3.4787)=1962.2291
# Epoch: 117, function value: f(3.4660)=1962.2172
# Epoch: 118, function value: f(3.4537)=1962.2058
# Epoch: 119, function value: f(3.4417)=1962.1951
# Epoch: 120, function value: f(3.4300)=1962.1849
# Epoch: 121, function value: f(3.4186)=1962.1753
# Epoch: 122, function value: f(3.4076)=1962.1661
# Epoch: 123, function value: f(3.3968)=1962.1574
# Epoch: 124, function value: f(3.3863)=1962.1492
# Epoch: 125, function value: f(3.3761)=1962.1414
# Epoch: 126, function value: f(3.3661)=1962.1340
# Epoch: 127, function value: f(3.3564)=1962.1270
# Epoch: 128, function value: f(3.3470)=1962.1204
# Epoch: 129, function value: f(3.3378)=1962.1141
# Epoch: 130, function value: f(3.3289)=1962.1082
# Epoch: 131, function value: f(3.3202)=1962.1025
# Epoch: 132, function value: f(3.3117)=1962.0972
# Epoch: 133, function value: f(3.3035)=1962.0921
# Epoch: 134, function value: f(3.2954)=1962.0873
# Epoch: 135, function value: f(3.2876)=1962.0827
# Epoch: 136, function value: f(3.2800)=1962.0784
# Epoch: 137, function value: f(3.2726)=1962.0743
# Epoch: 138, function value: f(3.2654)=1962.0704
# Epoch: 139, function value: f(3.2583)=1962.0667
# Epoch: 140, function value: f(3.2515)=1962.0633
# Epoch: 141, function value: f(3.2448)=1962.0599
# Epoch: 142, function value: f(3.2384)=1962.0568
# Epoch: 143, function value: f(3.2321)=1962.0538
# Epoch: 144, function value: f(3.2259)=1962.0510
# Epoch: 145, function value: f(3.2199)=1962.0484
# Epoch: 146, function value: f(3.2141)=1962.0458
# Epoch: 147, function value: f(3.2084)=1962.0434
# Epoch: 148, function value: f(3.2029)=1962.0412
# Epoch: 149, function value: f(3.1975)=1962.0390
# Epoch: 150, function value: f(3.1923)=1962.0370
# Epoch: 151, function value: f(3.1872)=1962.0351
# Epoch: 152, function value: f(3.1823)=1962.0332
# Epoch: 153, function value: f(3.1774)=1962.0315
# Epoch: 154, function value: f(3.1727)=1962.0298
# Epoch: 155, function value: f(3.1682)=1962.0283
# Epoch: 156, function value: f(3.1637)=1962.0268
# Epoch: 157, function value: f(3.1594)=1962.0254
# Epoch: 158, function value: f(3.1552)=1962.0241
# Epoch: 159, function value: f(3.1511)=1962.0228
# Epoch: 160, function value: f(3.1471)=1962.0216
# Epoch: 161, function value: f(3.1432)=1962.0205
# Epoch: 162, function value: f(3.1394)=1962.0194
# Epoch: 163, function value: f(3.1357)=1962.0184
# Epoch: 164, function value: f(3.1321)=1962.0174
# Epoch: 165, function value: f(3.1286)=1962.0165
# Epoch: 166, function value: f(3.1252)=1962.0157
# Epoch: 167, function value: f(3.1219)=1962.0149
# Epoch: 168, function value: f(3.1186)=1962.0141
# Epoch: 169, function value: f(3.1155)=1962.0133
# Epoch: 170, function value: f(3.1124)=1962.0126
# Epoch: 171, function value: f(3.1095)=1962.0120
# Epoch: 172, function value: f(3.1066)=1962.0114
# Epoch: 173, function value: f(3.1037)=1962.0108
# Epoch: 174, function value: f(3.1010)=1962.0102
# Epoch: 175, function value: f(3.0983)=1962.0097
# Epoch: 176, function value: f(3.0957)=1962.0092
# Epoch: 177, function value: f(3.0932)=1962.0087
# Epoch: 178, function value: f(3.0907)=1962.0082
# Epoch: 179, function value: f(3.0883)=1962.0078
# Epoch: 180, function value: f(3.0860)=1962.0074
# Epoch: 181, function value: f(3.0837)=1962.0070
# Epoch: 182, function value: f(3.0815)=1962.0066
# Epoch: 183, function value: f(3.0793)=1962.0063
# Epoch: 184, function value: f(3.0772)=1962.0060
# Epoch: 185, function value: f(3.0752)=1962.0057
# Epoch: 186, function value: f(3.0732)=1962.0054
# Epoch: 187, function value: f(3.0712)=1962.0051
# Epoch: 188, function value: f(3.0694)=1962.0048
# Epoch: 189, function value: f(3.0675)=1962.0046
# Epoch: 190, function value: f(3.0657)=1962.0043
# Epoch: 191, function value: f(3.0640)=1962.0041
# Epoch: 192, function value: f(3.0623)=1962.0039
# Epoch: 193, function value: f(3.0606)=1962.0037
# Epoch: 194, function value: f(3.0590)=1962.0035
# Epoch: 195, function value: f(3.0575)=1962.0033
# Epoch: 196, function value: f(3.0560)=1962.0031
# Epoch: 197, function value: f(3.0545)=1962.0030
# Epoch: 198, function value: f(3.0530)=1962.0028
# Epoch: 199, function value: f(3.0516)=1962.0027
# Epoch: 200, function value: f(3.0503)=1962.0025
# Epoch: 201, function value: f(3.0489)=1962.0024
# Epoch: 202, function value: f(3.0476)=1962.0023
# Epoch: 203, function value: f(3.0464)=1962.0022
# Epoch: 204, function value: f(3.0451)=1962.0020
# Epoch: 205, function value: f(3.0439)=1962.0019
# Epoch: 206, function value: f(3.0428)=1962.0018
# Epoch: 207, function value: f(3.0417)=1962.0017
# Epoch: 208, function value: f(3.0405)=1962.0016
# Epoch: 209, function value: f(3.0395)=1962.0016
# Epoch: 210, function value: f(3.0384)=1962.0015
# Epoch: 211, function value: f(3.0374)=1962.0014
# Epoch: 212, function value: f(3.0364)=1962.0013
# Epoch: 213, function value: f(3.0355)=1962.0013
# Epoch: 214, function value: f(3.0345)=1962.0012
# Epoch: 215, function value: f(3.0336)=1962.0011
# Epoch: 216, function value: f(3.0327)=1962.0011
# Epoch: 217, function value: f(3.0318)=1962.0010
# Epoch: 218, function value: f(3.0310)=1962.0010
# Epoch: 219, function value: f(3.0302)=1962.0009
# Epoch: 220, function value: f(3.0294)=1962.0009
# Epoch: 221, function value: f(3.0286)=1962.0008
# Epoch: 222, function value: f(3.0278)=1962.0008
# Epoch: 223, function value: f(3.0271)=1962.0007
# Epoch: 224, function value: f(3.0264)=1962.0007
# Epoch: 225, function value: f(3.0257)=1962.0007
# Epoch: 226, function value: f(3.0250)=1962.0006
# Epoch: 227, function value: f(3.0243)=1962.0006
# Epoch: 228, function value: f(3.0237)=1962.0006
# Epoch: 229, function value: f(3.0231)=1962.0005
# Epoch: 230, function value: f(3.0225)=1962.0005
# Epoch: 231, function value: f(3.0219)=1962.0005
# Epoch: 232, function value: f(3.0213)=1962.0005
# Epoch: 233, function value: f(3.0207)=1962.0004
# Epoch: 234, function value: f(3.0202)=1962.0004
# Epoch: 235, function value: f(3.0196)=1962.0004
# Epoch: 236, function value: f(3.0191)=1962.0004
# Epoch: 237, function value: f(3.0186)=1962.0003
# Epoch: 238, function value: f(3.0181)=1962.0003
# Epoch: 239, function value: f(3.0176)=1962.0003
# Epoch: 240, function value: f(3.0172)=1962.0003
# Epoch: 241, function value: f(3.0167)=1962.0003
# Epoch: 242, function value: f(3.0163)=1962.0003
# Epoch: 243, function value: f(3.0158)=1962.0003
# Epoch: 244, function value: f(3.0154)=1962.0002
# Epoch: 245, function value: f(3.0150)=1962.0002
# Epoch: 246, function value: f(3.0146)=1962.0002
# Epoch: 247, function value: f(3.0142)=1962.0002
# Epoch: 248, function value: f(3.0139)=1962.0002
# Epoch: 249, function value: f(3.0135)=1962.0002
# Epoch: 250, function value: f(3.0131)=1962.0002
# Epoch: 251, function value: f(3.0128)=1962.0002
# Epoch: 252, function value: f(3.0124)=1962.0002
# Epoch: 253, function value: f(3.0121)=1962.0001
# Epoch: 254, function value: f(3.0118)=1962.0001
# Epoch: 255, function value: f(3.0115)=1962.0001
# Epoch: 256, function value: f(3.0112)=1962.0001
# Epoch: 257, function value: f(3.0109)=1962.0001
# Epoch: 258, function value: f(3.0106)=1962.0001
# Epoch: 259, function value: f(3.0103)=1962.0001
# Epoch: 260, function value: f(3.0100)=1962.0001
# Epoch: 261, function value: f(3.0098)=1962.0001
# Epoch: 262, function value: f(3.0095)=1962.0001
# Epoch: 263, function value: f(3.0093)=1962.0001
# Epoch: 264, function value: f(3.0090)=1962.0001
# Epoch: 265, function value: f(3.0088)=1962.0001
# Epoch: 266, function value: f(3.0085)=1962.0001
# Epoch: 267, function value: f(3.0083)=1962.0001
# Epoch: 268, function value: f(3.0081)=1962.0001
# Epoch: 269, function value: f(3.0079)=1962.0001
# Epoch: 270, function value: f(3.0077)=1962.0001
# Epoch: 271, function value: f(3.0075)=1962.0001
# Epoch: 272, function value: f(3.0073)=1962.0001
# Epoch: 273, function value: f(3.0071)=1962.0001
# Epoch: 274, function value: f(3.0069)=1962.0000
# Epoch: 275, function value: f(3.0067)=1962.0000
# Epoch: 276, function value: f(3.0065)=1962.0000
# Epoch: 277, function value: f(3.0064)=1962.0000
# Epoch: 278, function value: f(3.0062)=1962.0000
# Epoch: 279, function value: f(3.0060)=1962.0000
# Epoch: 280, function value: f(3.0059)=1962.0000
# Epoch: 281, function value: f(3.0057)=1962.0000
# Epoch: 282, function value: f(3.0056)=1962.0000
# Epoch: 283, function value: f(3.0054)=1962.0000
# Epoch: 284, function value: f(3.0053)=1962.0000
# Epoch: 285, function value: f(3.0051)=1962.0000
# Epoch: 286, function value: f(3.0050)=1962.0000
# Epoch: 287, function value: f(3.0049)=1962.0000
# Epoch: 288, function value: f(3.0047)=1962.0000
# Epoch: 289, function value: f(3.0046)=1962.0000
# Epoch: 290, function value: f(3.0045)=1962.0000
# Epoch: 291, function value: f(3.0044)=1962.0000
# Epoch: 292, function value: f(3.0043)=1962.0000
# Epoch: 293, function value: f(3.0041)=1962.0000
# Epoch: 294, function value: f(3.0040)=1962.0000
# Epoch: 295, function value: f(3.0039)=1962.0000
# Epoch: 296, function value: f(3.0038)=1962.0000
# Epoch: 297, function value: f(3.0037)=1962.0000
# Epoch: 298, function value: f(3.0036)=1962.0000
# Epoch: 299, function value: f(3.0035)=1962.0000
# Epoch: 300, function value: f(3.0034)=1962.0000
# Epoch: 301, function value: f(3.0033)=1962.0000
# Epoch: 302, function value: f(3.0033)=1962.0000
# Epoch: 303, function value: f(3.0032)=1962.0000
# Epoch: 304, function value: f(3.0031)=1962.0000
# Epoch: 305, function value: f(3.0030)=1962.0000
# Epoch: 306, function value: f(3.0029)=1962.0000
# Epoch: 307, function value: f(3.0028)=1962.0000
# Epoch: 308, function value: f(3.0028)=1962.0000
# Epoch: 309, function value: f(3.0027)=1962.0000
# Epoch: 310, function value: f(3.0026)=1962.0000
# Epoch: 311, function value: f(3.0026)=1962.0000
# Epoch: 312, function value: f(3.0025)=1962.0000
# Epoch: 313, function value: f(3.0024)=1962.0000
# Epoch: 314, function value: f(3.0024)=1962.0000
# Epoch: 315, function value: f(3.0023)=1962.0000
# Epoch: 316, function value: f(3.0022)=1962.0000
# Epoch: 317, function value: f(3.0022)=1962.0000
# Epoch: 318, function value: f(3.0021)=1962.0000
# Epoch: 319, function value: f(3.0021)=1962.0000
# Epoch: 320, function value: f(3.0020)=1962.0000
# Epoch: 321, function value: f(3.0020)=1962.0000
# Epoch: 322, function value: f(3.0019)=1962.0000
# Epoch: 323, function value: f(3.0019)=1962.0000
# Epoch: 324, function value: f(3.0018)=1962.0000
# Epoch: 325, function value: f(3.0018)=1962.0000
# Epoch: 326, function value: f(3.0017)=1962.0000
# Epoch: 327, function value: f(3.0017)=1962.0000
# Epoch: 328, function value: f(3.0016)=1962.0000
# Epoch: 329, function value: f(3.0016)=1962.0000
# Epoch: 330, function value: f(3.0015)=1962.0000
# Epoch: 331, function value: f(3.0015)=1962.0000
# Epoch: 332, function value: f(3.0015)=1962.0000
# Epoch: 333, function value: f(3.0014)=1962.0000
# Epoch: 334, function value: f(3.0014)=1962.0000
# Epoch: 335, function value: f(3.0013)=1962.0000
# Epoch: 336, function value: f(3.0013)=1962.0000
# Epoch: 337, function value: f(3.0013)=1962.0000
# Epoch: 338, function value: f(3.0012)=1962.0000
# Epoch: 339, function value: f(3.0012)=1962.0000
# Epoch: 340, function value: f(3.0012)=1962.0000
# Epoch: 341, function value: f(3.0011)=1962.0000
# Epoch: 342, function value: f(3.0011)=1962.0000
# Epoch: 343, function value: f(3.0011)=1962.0000
# Epoch: 344, function value: f(3.0011)=1962.0000
# Epoch: 345, function value: f(3.0010)=1962.0000
# Epoch: 346, function value: f(3.0010)=1962.0000
# Epoch: 347, function value: f(3.0010)=1962.0000
# Epoch: 348, function value: f(3.0009)=1962.0000
# Epoch: 349, function value: f(3.0009)=1962.0000
# Epoch: 350, function value: f(3.0009)=1962.0000
# Epoch: 351, function value: f(3.0009)=1962.0000
# Epoch: 352, function value: f(3.0008)=1962.0000
# Epoch: 353, function value: f(3.0008)=1962.0000
# Epoch: 354, function value: f(3.0008)=1962.0000
# Epoch: 355, function value: f(3.0008)=1962.0000
# Epoch: 356, function value: f(3.0008)=1962.0000
# Epoch: 357, function value: f(3.0007)=1962.0000
# Epoch: 358, function value: f(3.0007)=1962.0000
# Epoch: 359, function value: f(3.0007)=1962.0000
# Epoch: 360, function value: f(3.0007)=1962.0000
# Epoch: 361, function value: f(3.0007)=1962.0000
# Epoch: 362, function value: f(3.0006)=1962.0000
# Epoch: 363, function value: f(3.0006)=1962.0000
# Epoch: 364, function value: f(3.0006)=1962.0000
# Epoch: 365, function value: f(3.0006)=1962.0000
# Epoch: 366, function value: f(3.0006)=1962.0000
# Epoch: 367, function value: f(3.0006)=1962.0000
# Epoch: 368, function value: f(3.0006)=1962.0000
# Epoch: 369, function value: f(3.0005)=1962.0000
# Epoch: 370, function value: f(3.0005)=1962.0000
# Epoch: 371, function value: f(3.0005)=1962.0000
# Epoch: 372, function value: f(3.0005)=1962.0000
# Epoch: 373, function value: f(3.0005)=1962.0000
# Epoch: 374, function value: f(3.0005)=1962.0000
# Epoch: 375, function value: f(3.0005)=1962.0000
# Epoch: 376, function value: f(3.0004)=1962.0000
# Epoch: 377, function value: f(3.0004)=1962.0000
# Epoch: 378, function value: f(3.0004)=1962.0000
# Epoch: 379, function value: f(3.0004)=1962.0000
# Epoch: 380, function value: f(3.0004)=1962.0000
# Epoch: 381, function value: f(3.0004)=1962.0000
# Epoch: 382, function value: f(3.0004)=1962.0000
# Epoch: 383, function value: f(3.0004)=1962.0000
# Epoch: 384, function value: f(3.0004)=1962.0000
# Epoch: 385, function value: f(3.0004)=1962.0000
# Epoch: 386, function value: f(3.0003)=1962.0000
# Epoch: 387, function value: f(3.0003)=1962.0000
# Epoch: 388, function value: f(3.0003)=1962.0000
# Epoch: 389, function value: f(3.0003)=1962.0000
# Epoch: 390, function value: f(3.0003)=1962.0000
# Epoch: 391, function value: f(3.0003)=1962.0000
# Epoch: 392, function value: f(3.0003)=1962.0000
# Epoch: 393, function value: f(3.0003)=1962.0000
# Epoch: 394, function value: f(3.0003)=1962.0000
# Epoch: 395, function value: f(3.0003)=1962.0000
# Epoch: 396, function value: f(3.0003)=1962.0000
# Epoch: 397, function value: f(3.0003)=1962.0000
# Epoch: 398, function value: f(3.0002)=1962.0000
# Epoch: 399, function value: f(3.0002)=1962.0000
# Epoch: 400, function value: f(3.0002)=1962.0000
#
# The approximate argument of the function: 3.0002
# The minimum approximate value of the function: 1962.0000
#
# Please observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.
