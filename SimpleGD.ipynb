# %%
w  = 10.0        # Random weight initialization
lr = 0.01        # Learning rate

# %% [markdown]
# ###### We are trying to find the appropriate value of w. So that we could find the minimum value of F(w).
# #### $$F(w) = w^2 - 6w + 1971$$

# %%
def F(w):
    return (w**2.0) - (6.0*w) + 1971

# %% [markdown]
# ###### The first-order derivative of the above F(w), is
# #### $$F'(w) = 2w - 6$$

# %%
def dF(w):
    return (2.0*w) - 6.0

# %% [markdown]
# ###### Gradient Descent Optimization, is
# #### $$w = w - \eta \nabla_{w} F(w) $$
# ###### Gradient Ascent Optimization, is
# #### $$w = w + \eta \nabla_{w} F(w) $$
# ###### But, we are using gradient descent optimization here. Yes, you can use gradient ascent optimization also. :) Oh! wait! Please, multiply by -1 with dF(x). Because, minimizing the F(x) is the same as maximizing the -F(x).

# %%
for epoch in range(1, 401): # Epoch
    print('Epoch: {}, function value: f({:.4f})={:.4f}'.format(epoch, w, F(w)))
    w = w - (lr * dF(w))   # Gradient Descent Optimization
    # w = w + (lr * -dF(w))  # Gradient Ascent Optimization


print('\nThe approximate argument of the function: {:.4f}'.format(w))
print('The minimum approximate value of the function: {:.4f}'.format(F(w)))
print('\n\033[1;31mPlease observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.')
# Out:
# Epoch: 1, function value: f(10.0000)=2011.0000
# Epoch: 2, function value: f(9.8600)=2009.0596
# Epoch: 3, function value: f(9.7228)=2007.1960
# Epoch: 4, function value: f(9.5883)=2005.4063
# Epoch: 5, function value: f(9.4566)=2003.6874
# Epoch: 6, function value: f(9.3274)=2002.0366
# Epoch: 7, function value: f(9.2009)=2000.4511
# Epoch: 8, function value: f(9.0769)=1998.9285
# Epoch: 9, function value: f(8.9553)=1997.4661
# Epoch: 10, function value: f(8.8362)=1996.0616
# Epoch: 11, function value: f(8.7195)=1994.7128
# Epoch: 12, function value: f(8.6051)=1993.4174
# Epoch: 13, function value: f(8.4930)=1992.1732
# Epoch: 14, function value: f(8.3832)=1990.9784
# Epoch: 15, function value: f(8.2755)=1989.8308
# Epoch: 16, function value: f(8.1700)=1988.7287
# Epoch: 17, function value: f(8.0666)=1987.6703
# Epoch: 18, function value: f(7.9653)=1986.6537
# Epoch: 19, function value: f(7.8659)=1985.6774
# Epoch: 20, function value: f(7.7686)=1984.7398
# Epoch: 21, function value: f(7.6733)=1983.8393
# Epoch: 22, function value: f(7.5798)=1982.9745
# Epoch: 23, function value: f(7.4882)=1982.1439
# Epoch: 24, function value: f(7.3984)=1981.3462
# Epoch: 25, function value: f(7.3105)=1980.5801
# Epoch: 26, function value: f(7.2243)=1979.8443
# Epoch: 27, function value: f(7.1398)=1979.1377
# Epoch: 28, function value: f(7.0570)=1978.4590
# Epoch: 29, function value: f(6.9758)=1977.8072
# Epoch: 30, function value: f(6.8963)=1977.1813
# Epoch: 31, function value: f(6.8184)=1976.5801
# Epoch: 32, function value: f(6.7420)=1976.0027
# Epoch: 33, function value: f(6.6672)=1975.4482
# Epoch: 34, function value: f(6.5938)=1974.9157
# Epoch: 35, function value: f(6.5220)=1974.4042
# Epoch: 36, function value: f(6.4515)=1973.9130
# Epoch: 37, function value: f(6.3825)=1973.4413
# Epoch: 38, function value: f(6.3148)=1972.9882
# Epoch: 39, function value: f(6.2485)=1972.5530
# Epoch: 40, function value: f(6.1836)=1972.1351
# Epoch: 41, function value: f(6.1199)=1971.7338
# Epoch: 42, function value: f(6.0575)=1971.3483
# Epoch: 43, function value: f(5.9964)=1970.9781
# Epoch: 44, function value: f(5.9364)=1970.6226
# Epoch: 45, function value: f(5.8777)=1970.2812
# Epoch: 46, function value: f(5.8201)=1969.9532
# Epoch: 47, function value: f(5.7637)=1969.6383
# Epoch: 48, function value: f(5.7085)=1969.3358
# Epoch: 49, function value: f(5.6543)=1969.0453
# Epoch: 50, function value: f(5.6012)=1968.7663
# Epoch: 51, function value: f(5.5492)=1968.4984
# Epoch: 52, function value: f(5.4982)=1968.2410
# Epoch: 53, function value: f(5.4482)=1967.9939
# Epoch: 54, function value: f(5.3993)=1967.7565
# Epoch: 55, function value: f(5.3513)=1967.5286
# Epoch: 56, function value: f(5.3043)=1967.3096
# Epoch: 57, function value: f(5.2582)=1967.0994
# Epoch: 58, function value: f(5.2130)=1966.8974
# Epoch: 59, function value: f(5.1688)=1966.7035
# Epoch: 60, function value: f(5.1254)=1966.5172
# Epoch: 61, function value: f(5.0829)=1966.3384
# Epoch: 62, function value: f(5.0412)=1966.1666
# Epoch: 63, function value: f(5.0004)=1966.0016
# Epoch: 64, function value: f(4.9604)=1965.8431
# Epoch: 65, function value: f(4.9212)=1965.6909
# Epoch: 66, function value: f(4.8828)=1965.5448
# Epoch: 67, function value: f(4.8451)=1965.4044
# Epoch: 68, function value: f(4.8082)=1965.2696
# Epoch: 69, function value: f(4.7720)=1965.1401
# Epoch: 70, function value: f(4.7366)=1965.0157
# Epoch: 71, function value: f(4.7019)=1964.8963
# Epoch: 72, function value: f(4.6678)=1964.7816
# Epoch: 73, function value: f(4.6345)=1964.6715
# Epoch: 74, function value: f(4.6018)=1964.5657
# Epoch: 75, function value: f(4.5697)=1964.4641
# Epoch: 76, function value: f(4.5383)=1964.3665
# Epoch: 77, function value: f(4.5076)=1964.2728
# Epoch: 78, function value: f(4.4774)=1964.1828
# Epoch: 79, function value: f(4.4479)=1964.0964
# Epoch: 80, function value: f(4.4189)=1964.0133
# Epoch: 81, function value: f(4.3905)=1963.9336
# Epoch: 82, function value: f(4.3627)=1963.8570
# Epoch: 83, function value: f(4.3355)=1963.7835
# Epoch: 84, function value: f(4.3088)=1963.7129
# Epoch: 85, function value: f(4.2826)=1963.6450
# Epoch: 86, function value: f(4.2569)=1963.5799
# Epoch: 87, function value: f(4.2318)=1963.5173
# Epoch: 88, function value: f(4.2072)=1963.4572
# Epoch: 89, function value: f(4.1830)=1963.3995
# Epoch: 90, function value: f(4.1594)=1963.3441
# Epoch: 91, function value: f(4.1362)=1963.2909
# Epoch: 92, function value: f(4.1135)=1963.2398
# Epoch: 93, function value: f(4.0912)=1963.1907
# Epoch: 94, function value: f(4.0694)=1963.1435
# Epoch: 95, function value: f(4.0480)=1963.0982
# Epoch: 96, function value: f(4.0270)=1963.0548
# Epoch: 97, function value: f(4.0065)=1963.0130
# Epoch: 98, function value: f(3.9863)=1962.9729
# Epoch: 99, function value: f(3.9666)=1962.9343
# Epoch: 100, function value: f(3.9473)=1962.8973
# Epoch: 101, function value: f(3.9283)=1962.8618
# Epoch: 102, function value: f(3.9098)=1962.8277
# Epoch: 103, function value: f(3.8916)=1962.7949
# Epoch: 104, function value: f(3.8737)=1962.7634
# Epoch: 105, function value: f(3.8563)=1962.7332
# Epoch: 106, function value: f(3.8391)=1962.7042
# Epoch: 107, function value: f(3.8224)=1962.6763
# Epoch: 108, function value: f(3.8059)=1962.6495
# Epoch: 109, function value: f(3.7898)=1962.6238
# Epoch: 110, function value: f(3.7740)=1962.5991
# Epoch: 111, function value: f(3.7585)=1962.5754
# Epoch: 112, function value: f(3.7433)=1962.5526
# Epoch: 113, function value: f(3.7285)=1962.5307
# Epoch: 114, function value: f(3.7139)=1962.5097
# Epoch: 115, function value: f(3.6996)=1962.4895
# Epoch: 116, function value: f(3.6856)=1962.4701
# Epoch: 117, function value: f(3.6719)=1962.4515
# Epoch: 118, function value: f(3.6585)=1962.4336
# Epoch: 119, function value: f(3.6453)=1962.4164
# Epoch: 120, function value: f(3.6324)=1962.3999
# Epoch: 121, function value: f(3.6198)=1962.3841
# Epoch: 122, function value: f(3.6074)=1962.3689
# Epoch: 123, function value: f(3.5952)=1962.3543
# Epoch: 124, function value: f(3.5833)=1962.3403
# Epoch: 125, function value: f(3.5717)=1962.3268
# Epoch: 126, function value: f(3.5602)=1962.3138
# Epoch: 127, function value: f(3.5490)=1962.3014
# Epoch: 128, function value: f(3.5380)=1962.2895
# Epoch: 129, function value: f(3.5273)=1962.2780
# Epoch: 130, function value: f(3.5167)=1962.2670
# Epoch: 131, function value: f(3.5064)=1962.2564
# Epoch: 132, function value: f(3.4963)=1962.2463
# Epoch: 133, function value: f(3.4863)=1962.2365
# Epoch: 134, function value: f(3.4766)=1962.2272
# Epoch: 135, function value: f(3.4671)=1962.2182
# Epoch: 136, function value: f(3.4577)=1962.2095
# Epoch: 137, function value: f(3.4486)=1962.2012
# Epoch: 138, function value: f(3.4396)=1962.1933
# Epoch: 139, function value: f(3.4308)=1962.1856
# Epoch: 140, function value: f(3.4222)=1962.1783
# Epoch: 141, function value: f(3.4138)=1962.1712
# Epoch: 142, function value: f(3.4055)=1962.1644
# Epoch: 143, function value: f(3.3974)=1962.1579
# Epoch: 144, function value: f(3.3894)=1962.1517
# Epoch: 145, function value: f(3.3816)=1962.1456
# Epoch: 146, function value: f(3.3740)=1962.1399
# Epoch: 147, function value: f(3.3665)=1962.1343
# Epoch: 148, function value: f(3.3592)=1962.1290
# Epoch: 149, function value: f(3.3520)=1962.1239
# Epoch: 150, function value: f(3.3450)=1962.1190
# Epoch: 151, function value: f(3.3381)=1962.1143
# Epoch: 152, function value: f(3.3313)=1962.1098
# Epoch: 153, function value: f(3.3247)=1962.1054
# Epoch: 154, function value: f(3.3182)=1962.1012
# Epoch: 155, function value: f(3.3118)=1962.0972
# Epoch: 156, function value: f(3.3056)=1962.0934
# Epoch: 157, function value: f(3.2995)=1962.0897
# Epoch: 158, function value: f(3.2935)=1962.0861
# Epoch: 159, function value: f(3.2876)=1962.0827
# Epoch: 160, function value: f(3.2819)=1962.0794
# Epoch: 161, function value: f(3.2762)=1962.0763
# Epoch: 162, function value: f(3.2707)=1962.0733
# Epoch: 163, function value: f(3.2653)=1962.0704
# Epoch: 164, function value: f(3.2600)=1962.0676
# Epoch: 165, function value: f(3.2548)=1962.0649
# Epoch: 166, function value: f(3.2497)=1962.0623
# Epoch: 167, function value: f(3.2447)=1962.0599
# Epoch: 168, function value: f(3.2398)=1962.0575
# Epoch: 169, function value: f(3.2350)=1962.0552
# Epoch: 170, function value: f(3.2303)=1962.0530
# Epoch: 171, function value: f(3.2257)=1962.0509
# Epoch: 172, function value: f(3.2212)=1962.0489
# Epoch: 173, function value: f(3.2168)=1962.0470
# Epoch: 174, function value: f(3.2124)=1962.0451
# Epoch: 175, function value: f(3.2082)=1962.0433
# Epoch: 176, function value: f(3.2040)=1962.0416
# Epoch: 177, function value: f(3.1999)=1962.0400
# Epoch: 178, function value: f(3.1959)=1962.0384
# Epoch: 179, function value: f(3.1920)=1962.0369
# Epoch: 180, function value: f(3.1882)=1962.0354
# Epoch: 181, function value: f(3.1844)=1962.0340
# Epoch: 182, function value: f(3.1807)=1962.0327
# Epoch: 183, function value: f(3.1771)=1962.0314
# Epoch: 184, function value: f(3.1736)=1962.0301
# Epoch: 185, function value: f(3.1701)=1962.0289
# Epoch: 186, function value: f(3.1667)=1962.0278
# Epoch: 187, function value: f(3.1634)=1962.0267
# Epoch: 188, function value: f(3.1601)=1962.0256
# Epoch: 189, function value: f(3.1569)=1962.0246
# Epoch: 190, function value: f(3.1538)=1962.0236
# Epoch: 191, function value: f(3.1507)=1962.0227
# Epoch: 192, function value: f(3.1477)=1962.0218
# Epoch: 193, function value: f(3.1447)=1962.0209
# Epoch: 194, function value: f(3.1418)=1962.0201
# Epoch: 195, function value: f(3.1390)=1962.0193
# Epoch: 196, function value: f(3.1362)=1962.0186
# Epoch: 197, function value: f(3.1335)=1962.0178
# Epoch: 198, function value: f(3.1308)=1962.0171
# Epoch: 199, function value: f(3.1282)=1962.0164
# Epoch: 200, function value: f(3.1256)=1962.0158
# Epoch: 201, function value: f(3.1231)=1962.0152
# Epoch: 202, function value: f(3.1207)=1962.0146
# Epoch: 203, function value: f(3.1182)=1962.0140
# Epoch: 204, function value: f(3.1159)=1962.0134
# Epoch: 205, function value: f(3.1136)=1962.0129
# Epoch: 206, function value: f(3.1113)=1962.0124
# Epoch: 207, function value: f(3.1091)=1962.0119
# Epoch: 208, function value: f(3.1069)=1962.0114
# Epoch: 209, function value: f(3.1047)=1962.0110
# Epoch: 210, function value: f(3.1026)=1962.0105
# Epoch: 211, function value: f(3.1006)=1962.0101
# Epoch: 212, function value: f(3.0986)=1962.0097
# Epoch: 213, function value: f(3.0966)=1962.0093
# Epoch: 214, function value: f(3.0947)=1962.0090
# Epoch: 215, function value: f(3.0928)=1962.0086
# Epoch: 216, function value: f(3.0909)=1962.0083
# Epoch: 217, function value: f(3.0891)=1962.0079
# Epoch: 218, function value: f(3.0873)=1962.0076
# Epoch: 219, function value: f(3.0856)=1962.0073
# Epoch: 220, function value: f(3.0839)=1962.0070
# Epoch: 221, function value: f(3.0822)=1962.0068
# Epoch: 222, function value: f(3.0805)=1962.0065
# Epoch: 223, function value: f(3.0789)=1962.0062
# Epoch: 224, function value: f(3.0774)=1962.0060
# Epoch: 225, function value: f(3.0758)=1962.0057
# Epoch: 226, function value: f(3.0743)=1962.0055
# Epoch: 227, function value: f(3.0728)=1962.0053
# Epoch: 228, function value: f(3.0714)=1962.0051
# Epoch: 229, function value: f(3.0699)=1962.0049
# Epoch: 230, function value: f(3.0685)=1962.0047
# Epoch: 231, function value: f(3.0672)=1962.0045
# Epoch: 232, function value: f(3.0658)=1962.0043
# Epoch: 233, function value: f(3.0645)=1962.0042
# Epoch: 234, function value: f(3.0632)=1962.0040
# Epoch: 235, function value: f(3.0619)=1962.0038
# Epoch: 236, function value: f(3.0607)=1962.0037
# Epoch: 237, function value: f(3.0595)=1962.0035
# Epoch: 238, function value: f(3.0583)=1962.0034
# Epoch: 239, function value: f(3.0571)=1962.0033
# Epoch: 240, function value: f(3.0560)=1962.0031
# Epoch: 241, function value: f(3.0549)=1962.0030
# Epoch: 242, function value: f(3.0538)=1962.0029
# Epoch: 243, function value: f(3.0527)=1962.0028
# Epoch: 244, function value: f(3.0516)=1962.0027
# Epoch: 245, function value: f(3.0506)=1962.0026
# Epoch: 246, function value: f(3.0496)=1962.0025
# Epoch: 247, function value: f(3.0486)=1962.0024
# Epoch: 248, function value: f(3.0476)=1962.0023
# Epoch: 249, function value: f(3.0467)=1962.0022
# Epoch: 250, function value: f(3.0457)=1962.0021
# Epoch: 251, function value: f(3.0448)=1962.0020
# Epoch: 252, function value: f(3.0439)=1962.0019
# Epoch: 253, function value: f(3.0431)=1962.0019
# Epoch: 254, function value: f(3.0422)=1962.0018
# Epoch: 255, function value: f(3.0414)=1962.0017
# Epoch: 256, function value: f(3.0405)=1962.0016
# Epoch: 257, function value: f(3.0397)=1962.0016
# Epoch: 258, function value: f(3.0389)=1962.0015
# Epoch: 259, function value: f(3.0381)=1962.0015
# Epoch: 260, function value: f(3.0374)=1962.0014
# Epoch: 261, function value: f(3.0366)=1962.0013
# Epoch: 262, function value: f(3.0359)=1962.0013
# Epoch: 263, function value: f(3.0352)=1962.0012
# Epoch: 264, function value: f(3.0345)=1962.0012
# Epoch: 265, function value: f(3.0338)=1962.0011
# Epoch: 266, function value: f(3.0331)=1962.0011
# Epoch: 267, function value: f(3.0325)=1962.0011
# Epoch: 268, function value: f(3.0318)=1962.0010
# Epoch: 269, function value: f(3.0312)=1962.0010
# Epoch: 270, function value: f(3.0305)=1962.0009
# Epoch: 271, function value: f(3.0299)=1962.0009
# Epoch: 272, function value: f(3.0293)=1962.0009
# Epoch: 273, function value: f(3.0287)=1962.0008
# Epoch: 274, function value: f(3.0282)=1962.0008
# Epoch: 275, function value: f(3.0276)=1962.0008
# Epoch: 276, function value: f(3.0271)=1962.0007
# Epoch: 277, function value: f(3.0265)=1962.0007
# Epoch: 278, function value: f(3.0260)=1962.0007
# Epoch: 279, function value: f(3.0255)=1962.0006
# Epoch: 280, function value: f(3.0250)=1962.0006
# Epoch: 281, function value: f(3.0245)=1962.0006
# Epoch: 282, function value: f(3.0240)=1962.0006
# Epoch: 283, function value: f(3.0235)=1962.0006
# Epoch: 284, function value: f(3.0230)=1962.0005
# Epoch: 285, function value: f(3.0226)=1962.0005
# Epoch: 286, function value: f(3.0221)=1962.0005
# Epoch: 287, function value: f(3.0217)=1962.0005
# Epoch: 288, function value: f(3.0212)=1962.0005
# Epoch: 289, function value: f(3.0208)=1962.0004
# Epoch: 290, function value: f(3.0204)=1962.0004
# Epoch: 291, function value: f(3.0200)=1962.0004
# Epoch: 292, function value: f(3.0196)=1962.0004
# Epoch: 293, function value: f(3.0192)=1962.0004
# Epoch: 294, function value: f(3.0188)=1962.0004
# Epoch: 295, function value: f(3.0184)=1962.0003
# Epoch: 296, function value: f(3.0181)=1962.0003
# Epoch: 297, function value: f(3.0177)=1962.0003
# Epoch: 298, function value: f(3.0173)=1962.0003
# Epoch: 299, function value: f(3.0170)=1962.0003
# Epoch: 300, function value: f(3.0167)=1962.0003
# Epoch: 301, function value: f(3.0163)=1962.0003
# Epoch: 302, function value: f(3.0160)=1962.0003
# Epoch: 303, function value: f(3.0157)=1962.0002
# Epoch: 304, function value: f(3.0154)=1962.0002
# Epoch: 305, function value: f(3.0151)=1962.0002
# Epoch: 306, function value: f(3.0148)=1962.0002
# Epoch: 307, function value: f(3.0145)=1962.0002
# Epoch: 308, function value: f(3.0142)=1962.0002
# Epoch: 309, function value: f(3.0139)=1962.0002
# Epoch: 310, function value: f(3.0136)=1962.0002
# Epoch: 311, function value: f(3.0133)=1962.0002
# Epoch: 312, function value: f(3.0131)=1962.0002
# Epoch: 313, function value: f(3.0128)=1962.0002
# Epoch: 314, function value: f(3.0126)=1962.0002
# Epoch: 315, function value: f(3.0123)=1962.0002
# Epoch: 316, function value: f(3.0121)=1962.0001
# Epoch: 317, function value: f(3.0118)=1962.0001
# Epoch: 318, function value: f(3.0116)=1962.0001
# Epoch: 319, function value: f(3.0113)=1962.0001
# Epoch: 320, function value: f(3.0111)=1962.0001
# Epoch: 321, function value: f(3.0109)=1962.0001
# Epoch: 322, function value: f(3.0107)=1962.0001
# Epoch: 323, function value: f(3.0105)=1962.0001
# Epoch: 324, function value: f(3.0103)=1962.0001
# Epoch: 325, function value: f(3.0101)=1962.0001
# Epoch: 326, function value: f(3.0099)=1962.0001
# Epoch: 327, function value: f(3.0097)=1962.0001
# Epoch: 328, function value: f(3.0095)=1962.0001
# Epoch: 329, function value: f(3.0093)=1962.0001
# Epoch: 330, function value: f(3.0091)=1962.0001
# Epoch: 331, function value: f(3.0089)=1962.0001
# Epoch: 332, function value: f(3.0087)=1962.0001
# Epoch: 333, function value: f(3.0086)=1962.0001
# Epoch: 334, function value: f(3.0084)=1962.0001
# Epoch: 335, function value: f(3.0082)=1962.0001
# Epoch: 336, function value: f(3.0081)=1962.0001
# Epoch: 337, function value: f(3.0079)=1962.0001
# Epoch: 338, function value: f(3.0077)=1962.0001
# Epoch: 339, function value: f(3.0076)=1962.0001
# Epoch: 340, function value: f(3.0074)=1962.0001
# Epoch: 341, function value: f(3.0073)=1962.0001
# Epoch: 342, function value: f(3.0071)=1962.0001
# Epoch: 343, function value: f(3.0070)=1962.0000
# Epoch: 344, function value: f(3.0068)=1962.0000
# Epoch: 345, function value: f(3.0067)=1962.0000
# Epoch: 346, function value: f(3.0066)=1962.0000
# Epoch: 347, function value: f(3.0064)=1962.0000
# Epoch: 348, function value: f(3.0063)=1962.0000
# Epoch: 349, function value: f(3.0062)=1962.0000
# Epoch: 350, function value: f(3.0061)=1962.0000
# Epoch: 351, function value: f(3.0059)=1962.0000
# Epoch: 352, function value: f(3.0058)=1962.0000
# Epoch: 353, function value: f(3.0057)=1962.0000
# Epoch: 354, function value: f(3.0056)=1962.0000
# Epoch: 355, function value: f(3.0055)=1962.0000
# Epoch: 356, function value: f(3.0054)=1962.0000
# Epoch: 357, function value: f(3.0053)=1962.0000
# Epoch: 358, function value: f(3.0052)=1962.0000
# Epoch: 359, function value: f(3.0051)=1962.0000
# Epoch: 360, function value: f(3.0050)=1962.0000
# Epoch: 361, function value: f(3.0049)=1962.0000
# Epoch: 362, function value: f(3.0048)=1962.0000
# Epoch: 363, function value: f(3.0047)=1962.0000
# Epoch: 364, function value: f(3.0046)=1962.0000
# Epoch: 365, function value: f(3.0045)=1962.0000
# Epoch: 366, function value: f(3.0044)=1962.0000
# Epoch: 367, function value: f(3.0043)=1962.0000
# Epoch: 368, function value: f(3.0042)=1962.0000
# Epoch: 369, function value: f(3.0041)=1962.0000
# Epoch: 370, function value: f(3.0041)=1962.0000
# Epoch: 371, function value: f(3.0040)=1962.0000
# Epoch: 372, function value: f(3.0039)=1962.0000
# Epoch: 373, function value: f(3.0038)=1962.0000
# Epoch: 374, function value: f(3.0037)=1962.0000
# Epoch: 375, function value: f(3.0037)=1962.0000
# Epoch: 376, function value: f(3.0036)=1962.0000
# Epoch: 377, function value: f(3.0035)=1962.0000
# Epoch: 378, function value: f(3.0034)=1962.0000
# Epoch: 379, function value: f(3.0034)=1962.0000
# Epoch: 380, function value: f(3.0033)=1962.0000
# Epoch: 381, function value: f(3.0032)=1962.0000
# Epoch: 382, function value: f(3.0032)=1962.0000
# Epoch: 383, function value: f(3.0031)=1962.0000
# Epoch: 384, function value: f(3.0031)=1962.0000
# Epoch: 385, function value: f(3.0030)=1962.0000
# Epoch: 386, function value: f(3.0029)=1962.0000
# Epoch: 387, function value: f(3.0029)=1962.0000
# Epoch: 388, function value: f(3.0028)=1962.0000
# Epoch: 389, function value: f(3.0028)=1962.0000
# Epoch: 390, function value: f(3.0027)=1962.0000
# Epoch: 391, function value: f(3.0027)=1962.0000
# Epoch: 392, function value: f(3.0026)=1962.0000
# Epoch: 393, function value: f(3.0025)=1962.0000
# Epoch: 394, function value: f(3.0025)=1962.0000
# Epoch: 395, function value: f(3.0024)=1962.0000
# Epoch: 396, function value: f(3.0024)=1962.0000
# Epoch: 397, function value: f(3.0023)=1962.0000
# Epoch: 398, function value: f(3.0023)=1962.0000
# Epoch: 399, function value: f(3.0023)=1962.0000
# Epoch: 400, function value: f(3.0022)=1962.0000
#
# The approximate argument of the function: 3.0022
# The minimum approximate value of the function: 1962.0000
#
# Please observe the values of the function, and you will see that gradient descent is trying to accurate in every iteration.
